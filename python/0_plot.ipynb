# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('weight_color_data.csv')
df[['Day', 'Temp', 'Rep']] = df['Label'].str.split('_', expand=True)
df.head()
# Out:
#    Label  Weight      R_Mean      R_Std      G_Mean      G_Std      B_Mean  \
# 0  0_5_1   158.9  202.031017  63.184791  206.361271  55.761869  195.552566
# 1  1_5_1   154.5  196.388049  57.669474  200.363846  50.615080  189.855627
# 2  2_5_1   149.7  196.586956  56.816229  200.405571  50.129378  190.606173
# 3  3_5_1   148.4  206.840822  58.391917  210.816657  51.437818  201.517561
# 4  4_5_1   147.5  207.421014  58.118789  211.122241  51.420555  202.135509
#
#        B_Std     H_Mean      H_Std  ...      V_Std      L_Mean      L_Std  \
# 0  74.087194  48.603222  56.316379  ...  55.870933  208.442289  55.784846
# 1  68.516092  63.280031  57.690568  ...  50.922278  203.303091  50.910815
# 2  67.044048  63.870066  57.068227  ...  50.424279  203.433086  50.298129
# 3  68.725207  52.674892  54.528216  ...  51.588476  212.927224  51.478033
# 4  68.412750  53.727779  56.380803  ...  51.545167  213.275613  51.336971
#
#        a_Mean     a_Std      b_Mean      b_Std  Day  Temp  Rep
# ...

# %%
sns.lineplot(data=df, x="Day", y="G_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='G_Std'>

# %%
sns.lineplot(data=df, x="Day", y="R_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='R_Std'>

# %%
sns.lineplot(data=df, x="Day", y="B_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='B_Std'>

# %%
sns.lineplot(data=df, x="Day", y="L_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='L_Std'>

# %%
sns.lineplot(data=df, x="Day", y="a_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='a_Std'>

# %%
sns.lineplot(data=df, x="Day", y="b_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='b_Std'>

# %%
sns.lineplot(data=df, x="Day", y="H_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='H_Std'>

# %%
sns.lineplot(data=df, x="Day", y="S_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='S_Std'>

# %%
sns.lineplot(data=df, x="Day", y="V_Std", hue="Temp", marker="o", linewidth=2, alpha=0.8)
# Out:
# <Axes: xlabel='Day', ylabel='V_Std'>
